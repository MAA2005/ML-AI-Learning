# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(a,b,c):
    return 3*a**2 + 2*b+ c

# %%
na =np.arange(-5, 5, 0.5)
na
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5])

# %%
print(f(na))
# Out:
# [66 41 22  9  2  1  6 17 34 57]

# %%
plt.plot(na,f(na))

# %%
a=2
b=3
c=a+b
h=0.001
print(f(a,b,c))
print(f(a+h,b,c))
# Out:
# 23
# 23.012003

# %%
print(f(a+h,b,c) - f(a,b,c)/h)
# Out:
# -22976.987997
