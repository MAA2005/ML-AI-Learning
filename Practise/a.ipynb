# %%
names=["Anas","Ahmed","Ali","Aly","Amr"]
ages=[20,21,22,23,24]
initials=[n[0] for n in names]
print(initials)
# Out:
# ['A', 'A', 'A', 'A', 'A']

# %%
z=zip(names,ages,initials)

# %%
print(list(z))
# Out:
# [('Anas', 20, 'A'), ('Ahmed', 21, 'A'), ('Ali', 22, 'A'), ('Aly', 23, 'A'), ('Amr', 24, 'A')]

# %%
print(z)

# %%
char=['a','b','c','d','e']
stoi ={s:i+1 for i,s in enumerate(char)}

# %%
stoi
